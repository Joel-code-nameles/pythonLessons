# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_loader = pd.read_csv('../DataHandeling/Panda/student_scores.csv')
data_loader.head()
# Out:
#     Name  Math  English  Science  ICT  Social_Studies  Participation
# 0    Ama    85       78       92   88              81              9
# 1   Kojo    70       65       75   60              72              7
# 2   Afia    95       90       88   94              91             10
# 3    Yaw    60       58       62   55              59              6
# 4  Kwame    88       82       84   86              80              8

# %%
print(data_loader)
# Out:
#      Name  Math  English  Science  ICT  Social_Studies  Participation
# 0     Ama    85       78       92   88              81              9
# 1    Kojo    70       65       75   60              72              7
# 2    Afia    95       90       88   94              91             10
# 3     Yaw    60       58       62   55              59              6
# 4   Kwame    88       82       84   86              80              8
# 5     Esi    75       70       73   71              76              7
# 6    Kofi    50       45       55   48              52              4
# 7  Akosua    92       95       91   89              93             10
# 8   Adjoa    66       60       64   63              67              6
# 9  Selorm    80       85       83   81              79              9

# %%
data_loader.tail()
# Out:
#      Name  Math  English  Science  ICT  Social_Studies  Participation
# 5     Esi    75       70       73   71              76              7
# 6    Kofi    50       45       55   48              52              4
# 7  Akosua    92       95       91   89              93             10
# 8   Adjoa    66       60       64   63              67              6
# 9  Selorm    80       85       83   81              79              9

# %%
data_loader.head(2)
# Out:
#    Name  Math  English  Science  ICT  Social_Studies  Participation
# 0   Ama    85       78       92   88              81              9
# 1  Kojo    70       65       75   60              72              7

# %%
data_loader.tail(2)
# Out:
#      Name  Math  English  Science  ICT  Social_Studies  Participation
# 8   Adjoa    66       60       64   63              67              6
# 9  Selorm    80       85       83   81              79              9

# %%
data_loader['Total'] = data_loader[['Math','English','Science','ICT','Social_Studies']].sum(axis = 1)

# %%
data_loader.head()
# Out:
#     Name  Math  English  Science  ICT  Social_Studies  Participation  Total
# 0    Ama    85       78       92   88              81              9    424
# 1   Kojo    70       65       75   60              72              7    342
# 2   Afia    95       90       88   94              91             10    458
# 3    Yaw    60       58       62   55              59              6    294
# 4  Kwame    88       82       84   86              80              8    420

# %%
data_loader['Average'] = data_loader[['Total']]/5

# %%
data_loader.head()
# Out:
#     Name  Math  English  Science  ICT  Social_Studies  Participation  Total  \
# 0    Ama    85       78       92   88              81              9    424
# 1   Kojo    70       65       75   60              72              7    342
# 2   Afia    95       90       88   94              91             10    458
# 3    Yaw    60       58       62   55              59              6    294
# 4  Kwame    88       82       84   86              80              8    420
#
#    Average
# 0     84.8
# 1     68.4
# 2     91.6
# 3     58.8
# 4     84.0

# %%
data_loader
# Out:
#      Name  Math  English  Science  ICT  Social_Studies  Participation  Total  \
# 0     Ama    85       78       92   88              81              9    424
# 1    Kojo    70       65       75   60              72              7    342
# 2    Afia    95       90       88   94              91             10    458
# 3     Yaw    60       58       62   55              59              6    294
# 4   Kwame    88       82       84   86              80              8    420
# 5     Esi    75       70       73   71              76              7    365
# 6    Kofi    50       45       55   48              52              4    250
# 7  Akosua    92       95       91   89              93             10    460
# 8   Adjoa    66       60       64   63              67              6    320
# 9  Selorm    80       85       83   81              79              9    408
#
#    Average
# 0     84.8
# 1     68.4
# 2     91.6
# 3     58.8
# 4     84.0
# 5     73.0
# 6     50.0
# 7     92.0
# ...

# %%
data_loader[["Math"]]
# Out:
#    Math
# 0    85
# 1    70
# 2    95
# 3    60
# 4    88
# 5    75
# 6    50
# 7    92
# 8    66
# 9    80

# %%
subjects = ['Math','English','Science','ICT','Social_Studies']

# %%
for subject in subjects:
    avg = data_loader[subject].mean()
    print(subject, avg)
    
lower_avg = min(subjects, key = lambda sugject: avg)
print("Lowest",lower_avg, avg)
# Out:
# Math 76.1
# English 72.8
# Science 76.7
# ICT 73.5
# Social_Studies 75.0
# Lowest Math 75.0

# %%
data_loader
# Out:
#      Name  Math  English  Science  ICT  Social_Studies  Participation  Total  \
# 0     Ama    85       78       92   88              81              9    424
# 1    Kojo    70       65       75   60              72              7    342
# 2    Afia    95       90       88   94              91             10    458
# 3     Yaw    60       58       62   55              59              6    294
# 4   Kwame    88       82       84   86              80              8    420
# 5     Esi    75       70       73   71              76              7    365
# 6    Kofi    50       45       55   48              52              4    250
# 7  Akosua    92       95       91   89              93             10    460
# 8   Adjoa    66       60       64   63              67              6    320
# 9  Selorm    80       85       83   81              79              9    408
#
#    Average
# 0     84.8
# 1     68.4
# 2     91.6
# 3     58.8
# 4     84.0
# 5     73.0
# 6     50.0
# 7     92.0
# ...

# %%
data_loader.sort_values(by="Total" , ascending = False).head(3)
# Out:
#      Name  Math  English  Science  ICT  Social_Studies  Participation  Total  \
# 7  Akosua    92       95       91   89              93             10    460
# 2    Afia    95       90       88   94              91             10    458
# 0     Ama    85       78       92   88              81              9    424
#
#    Average
# 7     92.0
# 2     91.6
# 0     84.8

# %%
data_loader[data_loader['Average'] < 70].sort_values(by = "Total", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data_loader[data_loader['Average'] < 70].sort_values(by = "Total", ascending = False)
#
# NameError: name 'data_loader' is not defined

# %%
plt.figure(figsize=(8,5))

plt.scatter(data_loader['Participation'], data_loader['Total'], color = "green")
plt.xlabel("Participation")
plt.ylabel("Total")
plt.grid(True)
plt.show()

# %%
avg_scores = [data_loader[subject].mean() for subject in subjects]

plt.bar(subjects, avg_scores, color='red')
plt.title("Average Score per Subject")
plt.ylabel("Score")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
